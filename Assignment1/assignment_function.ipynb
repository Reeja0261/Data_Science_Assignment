# %% [markdown]
# ### Assignment

# %%
#write a program that asks for three numbers and prints the largest using a function

a = int(input("enter first number"))
b = int(input("enter second number"))
c = int(input("enter third number"))
def large(a,b,c):
    if (a >=b and a >=c):
        return a
    elif (b >=a and b >=c):
        return b
    else:
        return c
large(a,b,c)
# Out:
# enter first number 5
# enter second number 5
# enter third number 4
# 5

# %%
# write a program that asks for 5 numbers and print the largest number

def largest(arr_):   #underscore gara variable bhayo
    max_number = arr_[0]
    for a in arr_[1:]:
        if a > max_number:
            max_number = a
        return max_number
largest([-1,-2,-7,-5,-5])
# Out:
# -1

# %%
# print a multiplication tabe for a number , but highlight multiples of 5
# roll a dice 10 times using random.randit() and count how many times you get it.
# ask the user to input a word and count vowels and consonants using a function.
# build a simple grade calculator for multiple students. input their marks in a list and print the grade using a function.

# %%
a = int(input("enter the number"))

def multiplication(a):
    for i in range(1,11):
        answer = a * i
        if answer % 5 == 0:
            print(f"{a} * {i} = {answer}")
        else:
            print(f"{a} * {i} = {answer}")
multiplication(a)
# Out:
# enter the number 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
import random

def dice():
    count = 0
    for i in range(10):
        r = random.randint(1, 6)
        print("Roll:", r)
        if r == 6:
            count += 1
    return count

print(dice())
# Out:
# Roll: 3
# Roll: 2
# Roll: 4
# Roll: 1
# Roll: 6
# Roll: 5
# Roll: 2
# Roll: 3
# Roll: 6
# Roll: 6
# 3

# %%
word = input("Enter a word: ")
def count_vc(word):
    vowels = "aeiouAEIOU"
    v = 0
    c = 0

    for ch in word:
        if ch.isalpha():       
            if ch in vowels:  
                v += 1
            else:             
                c += 1
    return v, c

v, c = count_vc(word)
print("Vowels =", v)
print("Consonants =", c)
# Out:
# Enter a word:  a
# Vowels = 1
# Consonants = 0

# %%
def grade(marks):
    avg = sum(marks) / len(marks)

    if avg >= 90:
        return "A"
    elif avg >= 80:
        return "B"
    elif avg >= 70:
        return "C"
    elif avg >= 60:
        return "D"
    else:
        return "F"

num = int(input("How many students? "))

for i in range(num):
    print("Student", i + 1)
    marks = list(map(int, input("Enter marks: ").split()))
    print("Grade =", grade(marks))
# Out:
# How many students?  2
# Student 1
# Enter marks:  100
# Grade = A
# Student 2
# Enter marks:  90
# Grade = A

# %%
from collections import deque

stack = deque()


stack.append(30)
stack.append(50)


print(stack.pop())   
print(stack.pop())
# Out:
# 50
# 30

# %%
class Stack:
    def __init__(s):
        s.items = []   

    def push(s, value):
        s.items.append(value)   

    def pop(s):
        if s.is_empty():
            return None            
        return s.items.pop()    

    def peek(s):
        if s.is_empty():
            return None
        return s.items[-1]      

    def is_empty(s):
        return len(s.items) == 0



s = Stack()
s.push(10)
s.push(10)
print(s.pop())  
print(s.pop())
# Out:
# 10
# 10

# %%
from collections import deque

queue = deque()

queue.append(40)
queue.append(50)
queue.append(60)

print(queue.popleft())   
print(queue.popleft())   
print(queue.popleft())
# Out:
# 40
# 50
# 60

# %%
class Queue:
    def __init__(q):
        q.items = []

    def enqueue(q, value):
        q.items.append(value)

    def dequeue(q):
        if q.is_empty():
            return None
        else:
            return q.items.pop(0)

    def is_empty(q):
        return len(q.items) == 0


q = Queue()
q.enqueue(10)
q.enqueue(20)
print(q.dequeue())  
print(q.dequeue())
# Out:
# 10
# 20

# %%
stack = []   


stack.append(50)
stack.append(80)


print(stack.pop())   
print(stack.pop())
# Out:
# 80
# 50

# %%
queue = []  


queue.append(90)
queue.append(100)
queue.append(300)


print(queue.pop())   
print(queue.pop())   
print(queue.pop())
# Out:
# 300
# 100
# 90

# %%
linked_list = []

linked_list.append(10)
linked_list.append(20)
linked_list.append(30)

linked_list.pop()
print("After removing first:", linked_list)  

linked_list.insert(0, 5)
print("After inserting at head:", linked_list)
# Out:
# After removing first: [10, 20]
# After inserting at head: [5, 10, 20]

# %%
class Node:
    def __init__(ll, data):
        ll.data = data
        ll.next = None  


class LinkedList:
    def __init__(ll):
        ll.head = None  

    
    def append(ll, data):
        new_node = Node(data)
        if not ll.head:
            ll.head = new_node
            return
        last = ll.head
        while last.next:
            last = last.next
        last.next = new_node

    
    def print(ll):
        current = ll.head
        while current:
            print(current.data, end=" - ")
            current = current.next
        print("end")


ll = LinkedList()
ll.append(80)
ll.append(90)
ll.append(100)

ll.print()
# Out:
# 80 - 90 - 100 - end

# %%
# 1. Node class
class Node:
    def __init__(self, data):
        self.data = data      # store value of node
        self.left = None      # left child
        self.right = None     # right child

# 2. Binary Tree class
class BinaryTree:
    def __init__(self, root_data):
        self.root = Node(root_data)  # create root node

# 3. Example: create tree manually
tree = BinaryTree(10)          # root = 10
tree.root.left = Node(5)       # left child of root
tree.root.right = Node(20)     # right child of root
tree.root.left.left = Node(3)  # left child of node 5
tree.root.left.right = Node(7) # right child of node 5

# %%
class Node:
    def __init__(self, data):
        self.data = data      
        self.left = None      
        self.right = None    


class BinaryTree:
    def __init__(self, root_data):
        self.root = Node(root_data)  


tree = BinaryTree(10)          
tree.root.left = Node(5)       
tree.root.right = Node(20)     
tree.root.left.left = Node(3)  
tree.root.left.right = Node(7) 
print(tree.root.data)             
print(tree.root.left.data)         
print(tree.root.right.data)        
print(tree.root.left.left.data)    
print(tree.root.left.right.data)
# Out:
# 10
# 5
# 20
# 3
# 7

# %%
linked_list = [10, 20, 30, 40] 
linked_list.insert(5, 50)     
linked_list.remove(10)           
print(linked_list)
# Out:
# [20, 30, 40, 50]

# %%
import heapq

heap = []

heapq.heappush(heap, 15)
heapq.heappush(heap, 5)
heapq.heappush(heap, 25)

print("Heap:", heap)
# Out:
# Heap: [5, 15, 25]
